# %%
import json
import pandas as pd

def extract_tweets_from_har(file_path):
    # Load HAR file
    with open(file_path, 'r', encoding='utf-8') as f:
        har_data = json.load(f)
    
    tweets = []
    # Iterate through HAR entries to extract tweets
    for entry_num, entry in enumerate(har_data['log']['entries']):
        if 'text' in entry['response']['content']:
            response_text = entry['response']['content']['text']
            try:
                response_json = json.loads(response_text)
                # Dig deeper into the JSON to account for possible structure variations
                tweet_texts = json_extract(response_json, 'full_text')
                tweet_times = json_extract(response_json, 'created_at')
                for tweet_text, tweet_time in zip(tweet_texts, tweet_times):
                    tweets.append({
                        "tweet_body": tweet_text,
                        "tweet_time": tweet_time
                    })
            except json.JSONDecodeError:
                print(f"Failed to process entry {entry_num} - possible structure discrepancy.")
    return tweets

def json_extract(obj, key):
    """Recursively fetch values from nested JSON."""
    arr = []
    def extract(obj, arr, key):
        if isinstance(obj, dict):
            for k, v in obj.items():
                if isinstance(v, (dict, list)):
                    extract(v, arr, key)
                elif k == key:
                    arr.append(v)
        elif isinstance(obj, list):
            for item in obj:
                extract(item, arr, key)
        return arr
    values = extract(obj, arr, key)
    return values

def tweets_to_dataframe(tweets):
    # Convert tweet details to Pandas DataFrame
    df = pd.DataFrame(tweets)
    
    # Add a binary flag for when tweet_body contains "Train"
    df['has_train'] = df['tweet_body'].apply(lambda x: 1 if "Train" in x else 0)
    
    return df

# Step 1: Extract tweets from HAR file
#har_file_path = "/Users/troys/OneDrive/Documents/Python/BeeEye/TRAINS - X HAR FILE/twitter.com.har"
har_file_path = "/Users/troys/OneDrive/Documents/Python/BeeEye/TRAINS - X HAR FILE/trains_Aug24_Oct22.har"
tweets = extract_tweets_from_har(har_file_path)

# Step 2: Convert to DataFrame
df = tweets_to_dataframe(tweets)

print(df)
# Out:
# Failed to process entry 0 - possible structure discrepancy.
# Failed to process entry 1 - possible structure discrepancy.
# Failed to process entry 2 - possible structure discrepancy.
# Failed to process entry 3 - possible structure discrepancy.
# Failed to process entry 4 - possible structure discrepancy.
# Failed to process entry 5 - possible structure discrepancy.
# Failed to process entry 7 - possible structure discrepancy.
# Failed to process entry 8 - possible structure discrepancy.
# Failed to process entry 9 - possible structure discrepancy.
# Failed to process entry 10 - possible structure discrepancy.
# Failed to process entry 11 - possible structure discrepancy.
# Failed to process entry 13 - possible structure discrepancy.
# Failed to process entry 14 - possible structure discrepancy.
# Failed to process entry 15 - possible structure discrepancy.
# Failed to process entry 16 - possible structure discrepancy.
# Failed to process entry 17 - possible structure discrepancy.
# Failed to process entry 18 - possible structure discrepancy.
# Failed to process entry 20 - possible structure discrepancy.
# Failed to process entry 21 - possible structure discrepancy.
# Failed to process entry 23 - possible structure discrepancy.
# Failed to process entry 26 - possible structure discrepancy.
# Failed to process entry 27 - possible structure discrepancy.
# Failed to process entry 28 - possible structure discrepancy.
# Failed to process entry 29 - possible structure discrepancy.
# Failed to process entry 30 - possible structure discrepancy.
# Failed to process entry 31 - possible structure discrepancy.
# Failed to process entry 32 - possible structure discrepancy.
# Failed to process entry 33 - possible structure discrepancy.
# Failed to process entry 35 - possible structure discrepancy.
# Failed to process entry 36 - possible structure discrepancy.
# Failed to process entry 37 - possible structure discrepancy.
# Failed to process entry 38 - possible structure discrepancy.
# Failed to process entry 40 - possible structure discrepancy.
# Failed to process entry 41 - possible structure discrepancy.
# Failed to process entry 42 - possible structure discrepancy.
# Failed to process entry 43 - possible structure discrepancy.
# Failed to process entry 44 - possible structure discrepancy.
# Failed to process entry 46 - possible structure discrepancy.
# Failed to process entry 47 - possible structure discrepancy.
# Failed to process entry 48 - possible structure discrepancy.
# Failed to process entry 50 - possible structure discrepancy.
# Failed to process entry 51 - possible structure discrepancy.
# Failed to process entry 54 - possible structure discrepancy.
# Failed to process entry 55 - possible structure discrepancy.
# Failed to process entry 56 - possible structure discrepancy.
# Failed to process entry 57 - possible structure discrepancy.
# Failed to process entry 58 - possible structure discrepancy.
# Failed to process entry 59 - possible structure discrepancy.
# Failed to process entry 60 - possible structure discrepancy.
# Failed to process entry 61 - possible structure discrepancy.
# Failed to process entry 63 - possible structure discrepancy.
# Failed to process entry 64 - possible structure discrepancy.
# Failed to process entry 65 - possible structure discrepancy.
# Failed to process entry 67 - possible structure discrepancy.
# Failed to process entry 68 - possible structure discrepancy.
# Failed to process entry 69 - possible structure discrepancy.
# Failed to process entry 70 - possible structure discrepancy.
# Failed to process entry 72 - possible structure discrepancy.
# Failed to process entry 73 - possible structure discrepancy.
# Failed to process entry 74 - possible structure discrepancy.
# Failed to process entry 75 - possible structure discrepancy.
# Failed to process entry 77 - possible structure discrepancy.
# Failed to process entry 78 - possible structure discrepancy.
# Failed to process entry 80 - possible structure discrepancy.
# Failed to process entry 81 - possible structure discrepancy.
# Failed to process entry 82 - possible structure discrepancy.
# Failed to process entry 83 - possible structure discrepancy.
# Failed to process entry 85 - possible structure discrepancy.
# Failed to process entry 86 - possible structure discrepancy.
# Failed to process entry 87 - possible structure discrepancy.
# Failed to process entry 91 - possible structure discrepancy.
# Failed to process entry 92 - possible structure discrepancy.
# Failed to process entry 93 - possible structure discrepancy.
# Failed to process entry 94 - possible structure discrepancy.
# Failed to process entry 95 - possible structure discrepancy.
# Failed to process entry 96 - possible structure discrepancy.
# Failed to process entry 97 - possible structure discrepancy.
# Failed to process entry 98 - possible structure discrepancy.
# Failed to process entry 101 - possible structure discrepancy.
# Failed to process entry 102 - possible structure discrepancy.
# Failed to process entry 103 - possible structure discrepancy.
# Failed to process entry 105 - possible structure discrepancy.
# Failed to process entry 106 - possible structure discrepancy.
# Failed to process entry 107 - possible structure discrepancy.
# Failed to process entry 108 - possible structure discrepancy.
# Failed to process entry 111 - possible structure discrepancy.
# Failed to process entry 112 - possible structure discrepancy.
# Failed to process entry 114 - possible structure discrepancy.
# Failed to process entry 115 - possible structure discrepancy.
# Failed to process entry 116 - possible structure discrepancy.
# Failed to process entry 117 - possible structure discrepancy.
# Failed to process entry 118 - possible structure discrepancy.
# Failed to process entry 119 - possible structure discrepancy.
# Failed to process entry 121 - possible structure discrepancy.
# Failed to process entry 122 - possible structure discrepancy.
# Failed to process entry 124 - possible structure discrepancy.
# Failed to process entry 127 - possible structure discrepancy.
# Failed to process entry 128 - possible structure discrepancy.
# Failed to process entry 129 - possible structure discrepancy.
# Failed to process entry 130 - possible structure discrepancy.
# Failed to process entry 131 - possible structure discrepancy.
# Failed to process entry 132 - possible structure discrepancy.
# Failed to process entry 134 - possible structure discrepancy.
# Failed to process entry 135 - possible structure discrepancy.
# Failed to process entry 137 - possible structure discrepancy.
# Failed to process entry 138 - possible structure discrepancy.
# Failed to process entry 139 - possible structure discrepancy.
# Failed to process entry 140 - possible structure discrepancy.
# Failed to process entry 142 - possible structure discrepancy.
# Failed to process entry 144 - possible structure discrepancy.
# Failed to process entry 145 - possible structure discrepancy.
# Failed to process entry 146 - possible structure discrepancy.
# Failed to process entry 147 - possible structure discrepancy.
# Failed to process entry 149 - possible structure discrepancy.
# Failed to process entry 150 - possible structure discrepancy.
# Failed to process entry 151 - possible structure discrepancy.
# Failed to process entry 153 - possible structure discrepancy.
# Failed to process entry 155 - possible structure discrepancy.
# Failed to process entry 157 - possible structure discrepancy.
# Failed to process entry 158 - possible structure discrepancy.
# Failed to process entry 159 - possible structure discrepancy.
# Failed to process entry 161 - possible structure discrepancy.
# Failed to process entry 162 - possible structure discrepancy.
# Failed to process entry 163 - possible structure discrepancy.
# Failed to process entry 167 - possible structure discrepancy.
# Failed to process entry 168 - possible structure discrepancy.
# Failed to process entry 169 - possible structure discrepancy.
# Failed to process entry 170 - possible structure discrepancy.
# Failed to process entry 171 - possible structure discrepancy.
# Failed to process entry 172 - possible structure discrepancy.
# Failed to process entry 173 - possible structure discrepancy.
# Failed to process entry 174 - possible structure discrepancy.
# Failed to process entry 175 - possible structure discrepancy.
# Failed to process entry 176 - possible structure discrepancy.
# Failed to process entry 177 - possible structure discrepancy.
# Failed to process entry 179 - possible structure discrepancy.
# Failed to process entry 180 - possible structure discrepancy.
# Failed to process entry 181 - possible structure discrepancy.
# Failed to process entry 182 - possible structure discrepancy.
# Failed to process entry 183 - possible structure discrepancy.
# Failed to process entry 184 - possible structure discrepancy.
# Failed to process entry 185 - possible structure discrepancy.
# Failed to process entry 186 - possible structure discrepancy.
# Failed to process entry 187 - possible structure discrepancy.
# Failed to process entry 189 - possible structure discrepancy.
# Failed to process entry 190 - possible structure discrepancy.
# Failed to process entry 191 - possible structure discrepancy.
# Failed to process entry 194 - possible structure discrepancy.
# Failed to process entry 195 - possible structure discrepancy.
# Failed to process entry 196 - possible structure discrepancy.
# Failed to process entry 197 - possible structure discrepancy.
# Failed to process entry 198 - possible structure discrepancy.
# Failed to process entry 199 - possible structure discrepancy.
# Failed to process entry 200 - possible structure discrepancy.
# Failed to process entry 201 - possible structure discrepancy.
# Failed to process entry 202 - possible structure discrepancy.
# Failed to process entry 203 - possible structure discrepancy.
# Failed to process entry 204 - possible structure discrepancy.
# Failed to process entry 205 - possible structure discrepancy.
# Failed to process entry 206 - possible structure discrepancy.
# Failed to process entry 208 - possible structure discrepancy.
# Failed to process entry 210 - possible structure discrepancy.
# Failed to process entry 211 - possible structure discrepancy.
# Failed to process entry 212 - possible structure discrepancy.
# Failed to process entry 213 - possible structure discrepancy.
# Failed to process entry 215 - possible structure discrepancy.
# Failed to process entry 216 - possible structure discrepancy.
# Failed to process entry 217 - possible structure discrepancy.
# Failed to process entry 218 - possible structure discrepancy.
# Failed to process entry 219 - possible structure discrepancy.
# Failed to process entry 224 - possible structure discrepancy.
# Failed to process entry 226 - possible structure discrepancy.
# Failed to process entry 227 - possible structure discrepancy.
# Failed to process entry 228 - possible structure discrepancy.
# Failed to process entry 230 - possible structure discrepancy.
# Failed to process entry 231 - possible structure discrepancy.
# Failed to process entry 232 - possible structure discrepancy.
# Failed to process entry 233 - possible structure discrepancy.
# Failed to process entry 234 - possible structure discrepancy.
# Failed to process entry 235 - possible structure discrepancy.
# Failed to process entry 236 - possible structure discrepancy.
# Failed to process entry 237 - possible structure discrepancy.
# Failed to process entry 239 - possible structure discrepancy.
# Failed to process entry 240 - possible structure discrepancy.
# Failed to process entry 242 - possible structure discrepancy.
# Failed to process entry 243 - possible structure discrepancy.
# Failed to process entry 245 - possible structure discrepancy.
# Failed to process entry 246 - possible structure discrepancy.
# Failed to process entry 247 - possible structure discrepancy.
# Failed to process entry 248 - possible structure discrepancy.
# Failed to process entry 249 - possible structure discrepancy.
# Failed to process entry 251 - possible structure discrepancy.
# Failed to process entry 253 - possible structure discrepancy.
# Failed to process entry 254 - possible structure discrepancy.
# Failed to process entry 255 - possible structure discrepancy.
# Failed to process entry 256 - possible structure discrepancy.
# Failed to process entry 258 - possible structure discrepancy.
# Failed to process entry 260 - possible structure discrepancy.
# Failed to process entry 261 - possible structure discrepancy.
# Failed to process entry 262 - possible structure discrepancy.
# Failed to process entry 263 - possible structure discrepancy.
# Failed to process entry 264 - possible structure discrepancy.
# Failed to process entry 266 - possible structure discrepancy.
# Failed to process entry 267 - possible structure discrepancy.
# Failed to process entry 269 - possible structure discrepancy.
# Failed to process entry 270 - possible structure discrepancy.
# Failed to process entry 271 - possible structure discrepancy.
# Failed to process entry 273 - possible structure discrepancy.
# Failed to process entry 274 - possible structure discrepancy.
# Failed to process entry 275 - possible structure discrepancy.
# Failed to process entry 276 - possible structure discrepancy.
# Failed to process entry 277 - possible structure discrepancy.
# Failed to process entry 278 - possible structure discrepancy.
# Failed to process entry 280 - possible structure discrepancy.
# Failed to process entry 281 - possible structure discrepancy.
# Failed to process entry 282 - possible structure discrepancy.
# Failed to process entry 286 - possible structure discrepancy.
# Failed to process entry 287 - possible structure discrepancy.
# Failed to process entry 288 - possible structure discrepancy.
# Failed to process entry 289 - possible structure discrepancy.
# Failed to process entry 290 - possible structure discrepancy.
# Failed to process entry 291 - possible structure discrepancy.
# Failed to process entry 292 - possible structure discrepancy.
# Failed to process entry 293 - possible structure discrepancy.
# Failed to process entry 294 - possible structure discrepancy.
# Failed to process entry 295 - possible structure discrepancy.
# Failed to process entry 297 - possible structure discrepancy.
# Failed to process entry 298 - possible structure discrepancy.
# Failed to process entry 299 - possible structure discrepancy.
# Failed to process entry 300 - possible structure discrepancy.
# Failed to process entry 302 - possible structure discrepancy.
# Failed to process entry 303 - possible structure discrepancy.
# Failed to process entry 304 - possible structure discrepancy.
# Failed to process entry 305 - possible structure discrepancy.
# Failed to process entry 307 - possible structure discrepancy.
# Failed to process entry 308 - possible structure discrepancy.
# Failed to process entry 309 - possible structure discrepancy.
# Failed to process entry 310 - possible structure discrepancy.
# Failed to process entry 311 - possible structure discrepancy.
# Failed to process entry 313 - possible structure discrepancy.
# Failed to process entry 314 - possible structure discrepancy.
# Failed to process entry 317 - possible structure discrepancy.
# Failed to process entry 318 - possible structure discrepancy.
# Failed to process entry 319 - possible structure discrepancy.
# Failed to process entry 320 - possible structure discrepancy.
# Failed to process entry 322 - possible structure discrepancy.
# Failed to process entry 323 - possible structure discrepancy.
# Failed to process entry 324 - possible structure discrepancy.
# Failed to process entry 325 - possible structure discrepancy.
# Failed to process entry 326 - possible structure discrepancy.
# Failed to process entry 327 - possible structure discrepancy.
# Failed to process entry 328 - possible structure discrepancy.
# Failed to process entry 329 - possible structure discrepancy.
# Failed to process entry 330 - possible structure discrepancy.
# Failed to process entry 332 - possible structure discrepancy.
# Failed to process entry 333 - possible structure discrepancy.
# Failed to process entry 334 - possible structure discrepancy.
# Failed to process entry 335 - possible structure discrepancy.
# Failed to process entry 336 - possible structure discrepancy.
# Failed to process entry 338 - possible structure discrepancy.
# Failed to process entry 339 - possible structure discrepancy.
# Failed to process entry 340 - possible structure discrepancy.
# Failed to process entry 341 - possible structure discrepancy.
# Failed to process entry 342 - possible structure discrepancy.
# Failed to process entry 345 - possible structure discrepancy.
# Failed to process entry 346 - possible structure discrepancy.
# Failed to process entry 347 - possible structure discrepancy.
# Failed to process entry 348 - possible structure discrepancy.
# Failed to process entry 349 - possible structure discrepancy.
# Failed to process entry 350 - possible structure discrepancy.
# Failed to process entry 351 - possible structure discrepancy.
# Failed to process entry 353 - possible structure discrepancy.
# Failed to process entry 354 - possible structure discrepancy.
# Failed to process entry 355 - possible structure discrepancy.
# Failed to process entry 356 - possible structure discrepancy.
# Failed to process entry 357 - possible structure discrepancy.
# Failed to process entry 358 - possible structure discrepancy.
# Failed to process entry 359 - possible structure discrepancy.
# Failed to process entry 361 - possible structure discrepancy.
# Failed to process entry 362 - possible structure discrepancy.
# Failed to process entry 363 - possible structure discrepancy.
# Failed to process entry 364 - possible structure discrepancy.
# Failed to process entry 365 - possible structure discrepancy.
# Failed to process entry 366 - possible structure discrepancy.
# Failed to process entry 368 - possible structure discrepancy.
# Failed to process entry 369 - possible structure discrepancy.
# Failed to process entry 370 - possible structure discrepancy.
# Failed to process entry 372 - possible structure discrepancy.
# Failed to process entry 373 - possible structure discrepancy.
# Failed to process entry 374 - possible structure discrepancy.
# Failed to process entry 377 - possible structure discrepancy.
# Failed to process entry 378 - possible structure discrepancy.
# Failed to process entry 379 - possible structure discrepancy.
# Failed to process entry 380 - possible structure discrepancy.
# Failed to process entry 381 - possible structure discrepancy.
# Failed to process entry 382 - possible structure discrepancy.
# Failed to process entry 383 - possible structure discrepancy.
# Failed to process entry 384 - possible structure discrepancy.
# Failed to process entry 385 - possible structure discrepancy.
# Failed to process entry 387 - possible structure discrepancy.
# Failed to process entry 388 - possible structure discrepancy.
# Failed to process entry 389 - possible structure discrepancy.
# Failed to process entry 390 - possible structure discrepancy.
# Failed to process entry 391 - possible structure discrepancy.
# Failed to process entry 392 - possible structure discrepancy.
# Failed to process entry 393 - possible structure discrepancy.
# Failed to process entry 395 - possible structure discrepancy.
# Failed to process entry 396 - possible structure discrepancy.
# Failed to process entry 397 - possible structure discrepancy.
# Failed to process entry 398 - possible structure discrepancy.
# Failed to process entry 399 - possible structure discrepancy.
# Failed to process entry 400 - possible structure discrepancy.
# Failed to process entry 401 - possible structure discrepancy.
# Failed to process entry 402 - possible structure discrepancy.
# Failed to process entry 403 - possible structure discrepancy.
# Failed to process entry 404 - possible structure discrepancy.
# Failed to process entry 405 - possible structure discrepancy.
# Failed to process entry 408 - possible structure discrepancy.
# Failed to process entry 409 - possible structure discrepancy.
# Failed to process entry 412 - possible structure discrepancy.
# Failed to process entry 413 - possible structure discrepancy.
# Failed to process entry 414 - possible structure discrepancy.
# Failed to process entry 415 - possible structure discrepancy.
# Failed to process entry 416 - possible structure discrepancy.
# Failed to process entry 417 - possible structure discrepancy.
# Failed to process entry 419 - possible structure discrepancy.
# Failed to process entry 420 - possible structure discrepancy.
# Failed to process entry 421 - possible structure discrepancy.
# Failed to process entry 422 - possible structure discrepancy.
# Failed to process entry 424 - possible structure discrepancy.
# Failed to process entry 426 - possible structure discrepancy.
# Failed to process entry 427 - possible structure discrepancy.
# Failed to process entry 428 - possible structure discrepancy.
# Failed to process entry 429 - possible structure discrepancy.
# Failed to process entry 430 - possible structure discrepancy.
# Failed to process entry 431 - possible structure discrepancy.
# Failed to process entry 433 - possible structure discrepancy.
# Failed to process entry 434 - possible structure discrepancy.
# Failed to process entry 435 - possible structure discrepancy.
# Failed to process entry 436 - possible structure discrepancy.
# Failed to process entry 437 - possible structure discrepancy.
# Failed to process entry 438 - possible structure discrepancy.
# Failed to process entry 439 - possible structure discrepancy.
# Failed to process entry 443 - possible structure discrepancy.
# Failed to process entry 444 - possible structure discrepancy.
# Failed to process entry 445 - possible structure discrepancy.
# Failed to process entry 446 - possible structure discrepancy.
# Failed to process entry 447 - possible structure discrepancy.
# Failed to process entry 448 - possible structure discrepancy.
# Failed to process entry 449 - possible structure discrepancy.
# Failed to process entry 450 - possible structure discrepancy.
# Failed to process entry 451 - possible structure discrepancy.
# Failed to process entry 452 - possible structure discrepancy.
# Failed to process entry 453 - possible structure discrepancy.
# Failed to process entry 454 - possible structure discrepancy.
# Failed to process entry 456 - possible structure discrepancy.
# Failed to process entry 457 - possible structure discrepancy.
# Failed to process entry 458 - possible structure discrepancy.
# Failed to process entry 459 - possible structure discrepancy.
# Failed to process entry 460 - possible structure discrepancy.
# Failed to process entry 461 - possible structure discrepancy.
# Failed to process entry 462 - possible structure discrepancy.
# Failed to process entry 464 - possible structure discrepancy.
# Failed to process entry 465 - possible structure discrepancy.
# Failed to process entry 466 - possible structure discrepancy.
# Failed to process entry 469 - possible structure discrepancy.
# Failed to process entry 470 - possible structure discrepancy.
# Failed to process entry 471 - possible structure discrepancy.
# Failed to process entry 472 - possible structure discrepancy.
# Failed to process entry 473 - possible structure discrepancy.
# Failed to process entry 474 - possible structure discrepancy.
# Failed to process entry 475 - possible structure discrepancy.
# Failed to process entry 476 - possible structure discrepancy.
# Failed to process entry 477 - possible structure discrepancy.
# Failed to process entry 479 - possible structure discrepancy.
# Failed to process entry 480 - possible structure discrepancy.
# Failed to process entry 481 - possible structure discrepancy.
# Failed to process entry 482 - possible structure discrepancy.
# Failed to process entry 483 - possible structure discrepancy.
# Failed to process entry 484 - possible structure discrepancy.
# Failed to process entry 485 - possible structure discrepancy.
# Failed to process entry 486 - possible structure discrepancy.
# Failed to process entry 488 - possible structure discrepancy.
# Failed to process entry 489 - possible structure discrepancy.
# Failed to process entry 490 - possible structure discrepancy.
# Failed to process entry 491 - possible structure discrepancy.
# Failed to process entry 492 - possible structure discrepancy.
# Failed to process entry 493 - possible structure discrepancy.
# Failed to process entry 497 - possible structure discrepancy.
# Failed to process entry 498 - possible structure discrepancy.
# Failed to process entry 499 - possible structure discrepancy.
# Failed to process entry 500 - possible structure discrepancy.
# Failed to process entry 501 - possible structure discrepancy.
# Failed to process entry 502 - possible structure discrepancy.
# Failed to process entry 503 - possible structure discrepancy.
# Failed to process entry 504 - possible structure discrepancy.
# Failed to process entry 505 - possible structure discrepancy.
# Failed to process entry 506 - possible structure discrepancy.
# Failed to process entry 507 - possible structure discrepancy.
# Failed to process entry 508 - possible structure discrepancy.
# Failed to process entry 509 - possible structure discrepancy.
# Failed to process entry 511 - possible structure discrepancy.
# Failed to process entry 512 - possible structure discrepancy.
# Failed to process entry 513 - possible structure discrepancy.
# Failed to process entry 514 - possible structure discrepancy.
# Failed to process entry 516 - possible structure discrepancy.
# Failed to process entry 517 - possible structure discrepancy.
# Failed to process entry 518 - possible structure discrepancy.
# Failed to process entry 519 - possible structure discrepancy.
# Failed to process entry 520 - possible structure discrepancy.
# Failed to process entry 522 - possible structure discrepancy.
# Failed to process entry 523 - possible structure discrepancy.
# Failed to process entry 525 - possible structure discrepancy.
# Failed to process entry 526 - possible structure discrepancy.
# Failed to process entry 527 - possible structure discrepancy.
# Failed to process entry 528 - possible structure discrepancy.
# Failed to process entry 529 - possible structure discrepancy.
# Failed to process entry 530 - possible structure discrepancy.
# Failed to process entry 531 - possible structure discrepancy.
# Failed to process entry 533 - possible structure discrepancy.
# Failed to process entry 534 - possible structure discrepancy.
# Failed to process entry 535 - possible structure discrepancy.
# Failed to process entry 536 - possible structure discrepancy.
# Failed to process entry 537 - possible structure discrepancy.
# Failed to process entry 539 - possible structure discrepancy.
# Failed to process entry 540 - possible structure discrepancy.
# Failed to process entry 541 - possible structure discrepancy.
# Failed to process entry 542 - possible structure discrepancy.
# Failed to process entry 543 - possible structure discrepancy.
# Failed to process entry 544 - possible structure discrepancy.
# Failed to process entry 545 - possible structure discrepancy.
# Failed to process entry 546 - possible structure discrepancy.
# Failed to process entry 547 - possible structure discrepancy.
# Failed to process entry 549 - possible structure discrepancy.
# Failed to process entry 552 - possible structure discrepancy.
# Failed to process entry 553 - possible structure discrepancy.
# Failed to process entry 554 - possible structure discrepancy.
# Failed to process entry 555 - possible structure discrepancy.
# Failed to process entry 556 - possible structure discrepancy.
# Failed to process entry 557 - possible structure discrepancy.
# Failed to process entry 558 - possible structure discrepancy.
# Failed to process entry 560 - possible structure discrepancy.
# Failed to process entry 561 - possible structure discrepancy.
# Failed to process entry 562 - possible structure discrepancy.
# Failed to process entry 563 - possible structure discrepancy.
# Failed to process entry 564 - possible structure discrepancy.
# Failed to process entry 565 - possible structure discrepancy.
# Failed to process entry 566 - possible structure discrepancy.
# Failed to process entry 567 - possible structure discrepancy.
# Failed to process entry 568 - possible structure discrepancy.
# Failed to process entry 570 - possible structure discrepancy.
# Failed to process entry 571 - possible structure discrepancy.
# Failed to process entry 572 - possible structure discrepancy.
# Failed to process entry 573 - possible structure discrepancy.
# Failed to process entry 574 - possible structure discrepancy.
# Failed to process entry 575 - possible structure discrepancy.
# Failed to process entry 579 - possible structure discrepancy.
# Failed to process entry 580 - possible structure discrepancy.
# Failed to process entry 581 - possible structure discrepancy.
# Failed to process entry 582 - possible structure discrepancy.
# Failed to process entry 583 - possible structure discrepancy.
# Failed to process entry 584 - possible structure discrepancy.
# Failed to process entry 585 - possible structure discrepancy.
# Failed to process entry 586 - possible structure discrepancy.
# Failed to process entry 587 - possible structure discrepancy.
# Failed to process entry 588 - possible structure discrepancy.
# Failed to process entry 589 - possible structure discrepancy.
# Failed to process entry 590 - possible structure discrepancy.
# Failed to process entry 592 - possible structure discrepancy.
# Failed to process entry 593 - possible structure discrepancy.
# Failed to process entry 594 - possible structure discrepancy.
# Failed to process entry 595 - possible structure discrepancy.
# Failed to process entry 597 - possible structure discrepancy.
# Failed to process entry 598 - possible structure discrepancy.
# Failed to process entry 599 - possible structure discrepancy.
# Failed to process entry 600 - possible structure discrepancy.
# Failed to process entry 601 - possible structure discrepancy.
# Failed to process entry 603 - possible structure discrepancy.
# Failed to process entry 605 - possible structure discrepancy.
# Failed to process entry 606 - possible structure discrepancy.
# Failed to process entry 608 - possible structure discrepancy.
# Failed to process entry 609 - possible structure discrepancy.
# Failed to process entry 610 - possible structure discrepancy.
# Failed to process entry 611 - possible structure discrepancy.
# Failed to process entry 612 - possible structure discrepancy.
# Failed to process entry 613 - possible structure discrepancy.
# Failed to process entry 614 - possible structure discrepancy.
# Failed to process entry 615 - possible structure discrepancy.
# Failed to process entry 616 - possible structure discrepancy.
# Failed to process entry 617 - possible structure discrepancy.
# Failed to process entry 619 - possible structure discrepancy.
# Failed to process entry 620 - possible structure discrepancy.
# Failed to process entry 621 - possible structure discrepancy.
# Failed to process entry 625 - possible structure discrepancy.
# Failed to process entry 626 - possible structure discrepancy.
# Failed to process entry 627 - possible structure discrepancy.
# Failed to process entry 628 - possible structure discrepancy.
# Failed to process entry 630 - possible structure discrepancy.
# Failed to process entry 631 - possible structure discrepancy.
# Failed to process entry 632 - possible structure discrepancy.
# Failed to process entry 633 - possible structure discrepancy.
# Failed to process entry 634 - possible structure discrepancy.
# Failed to process entry 635 - possible structure discrepancy.
# Failed to process entry 636 - possible structure discrepancy.
# Failed to process entry 637 - possible structure discrepancy.
# Failed to process entry 640 - possible structure discrepancy.
# Failed to process entry 641 - possible structure discrepancy.
# Failed to process entry 642 - possible structure discrepancy.
# Failed to process entry 643 - possible structure discrepancy.
# Failed to process entry 644 - possible structure discrepancy.
# Failed to process entry 645 - possible structure discrepancy.
# Failed to process entry 646 - possible structure discrepancy.
# Failed to process entry 649 - possible structure discrepancy.
# Failed to process entry 650 - possible structure discrepancy.
# Failed to process entry 651 - possible structure discrepancy.
# Failed to process entry 652 - possible structure discrepancy.
# Failed to process entry 653 - possible structure discrepancy.
# Failed to process entry 655 - possible structure discrepancy.
# Failed to process entry 656 - possible structure discrepancy.
# Failed to process entry 657 - possible structure discrepancy.
# Failed to process entry 658 - possible structure discrepancy.
# Failed to process entry 659 - possible structure discrepancy.
# Failed to process entry 660 - possible structure discrepancy.
# Failed to process entry 661 - possible structure discrepancy.
# Failed to process entry 663 - possible structure discrepancy.
# Failed to process entry 664 - possible structure discrepancy.
# Failed to process entry 666 - possible structure discrepancy.
# Failed to process entry 668 - possible structure discrepancy.
# Failed to process entry 669 - possible structure discrepancy.
# Failed to process entry 670 - possible structure discrepancy.
# Failed to process entry 671 - possible structure discrepancy.
# Failed to process entry 672 - possible structure discrepancy.
# Failed to process entry 673 - possible structure discrepancy.
# Failed to process entry 674 - possible structure discrepancy.
# Failed to process entry 675 - possible structure discrepancy.
# Failed to process entry 676 - possible structure discrepancy.
# Failed to process entry 677 - possible structure discrepancy.
# Failed to process entry 678 - possible structure discrepancy.
# Failed to process entry 680 - possible structure discrepancy.
# Failed to process entry 681 - possible structure discrepancy.
# Failed to process entry 682 - possible structure discrepancy.
# Failed to process entry 683 - possible structure discrepancy.
# Failed to process entry 684 - possible structure discrepancy.
# Failed to process entry 685 - possible structure discrepancy.
# Failed to process entry 687 - possible structure discrepancy.
# Failed to process entry 688 - possible structure discrepancy.
# Failed to process entry 689 - possible structure discrepancy.
# Failed to process entry 690 - possible structure discrepancy.
# Failed to process entry 692 - possible structure discrepancy.
# Failed to process entry 694 - possible structure discrepancy.
# Failed to process entry 695 - possible structure discrepancy.
# Failed to process entry 696 - possible structure discrepancy.
# Failed to process entry 697 - possible structure discrepancy.
# Failed to process entry 698 - possible structure discrepancy.
# Failed to process entry 699 - possible structure discrepancy.
# Failed to process entry 700 - possible structure discrepancy.
# Failed to process entry 701 - possible structure discrepancy.
# Failed to process entry 702 - possible structure discrepancy.
# Failed to process entry 703 - possible structure discrepancy.
# Failed to process entry 705 - possible structure discrepancy.
# Failed to process entry 706 - possible structure discrepancy.
# Failed to process entry 707 - possible structure discrepancy.
# Failed to process entry 708 - possible structure discrepancy.
# Failed to process entry 709 - possible structure discrepancy.
# Failed to process entry 710 - possible structure discrepancy.
# Failed to process entry 712 - possible structure discrepancy.
# Failed to process entry 713 - possible structure discrepancy.
# Failed to process entry 714 - possible structure discrepancy.
# Failed to process entry 715 - possible structure discrepancy.
# Failed to process entry 716 - possible structure discrepancy.
# Failed to process entry 717 - possible structure discrepancy.
# Failed to process entry 720 - possible structure discrepancy.
# Failed to process entry 721 - possible structure discrepancy.
# Failed to process entry 722 - possible structure discrepancy.
# Failed to process entry 724 - possible structure discrepancy.
# Failed to process entry 725 - possible structure discrepancy.
# Failed to process entry 726 - possible structure discrepancy.
# Failed to process entry 727 - possible structure discrepancy.
# Failed to process entry 728 - possible structure discrepancy.
# Failed to process entry 729 - possible structure discrepancy.
# Failed to process entry 730 - possible structure discrepancy.
# Failed to process entry 731 - possible structure discrepancy.
# Failed to process entry 732 - possible structure discrepancy.
# Failed to process entry 733 - possible structure discrepancy.
# Failed to process entry 735 - possible structure discrepancy.
# Failed to process entry 736 - possible structure discrepancy.
# Failed to process entry 737 - possible structure discrepancy.
# Failed to process entry 739 - possible structure discrepancy.
# Failed to process entry 740 - possible structure discrepancy.
# Failed to process entry 741 - possible structure discrepancy.
# Failed to process entry 742 - possible structure discrepancy.
# Failed to process entry 743 - possible structure discrepancy.
# Failed to process entry 744 - possible structure discrepancy.
# Failed to process entry 745 - possible structure discrepancy.
# Failed to process entry 747 - possible structure discrepancy.
# Failed to process entry 748 - possible structure discrepancy.
# Failed to process entry 750 - possible structure discrepancy.
# Failed to process entry 751 - possible structure discrepancy.
# Failed to process entry 753 - possible structure discrepancy.
# Failed to process entry 754 - possible structure discrepancy.
# Failed to process entry 760 - possible structure discrepancy.
# Failed to process entry 761 - possible structure discrepancy.
# Failed to process entry 764 - possible structure discrepancy.
# Failed to process entry 765 - possible structure discrepancy.
# Failed to process entry 766 - possible structure discrepancy.
# Failed to process entry 767 - possible structure discrepancy.
# Failed to process entry 768 - possible structure discrepancy.
# Failed to process entry 771 - possible structure discrepancy.
# Failed to process entry 772 - possible structure discrepancy.
# Failed to process entry 773 - possible structure discrepancy.
# Failed to process entry 774 - possible structure discrepancy.
# Failed to process entry 775 - possible structure discrepancy.
# Failed to process entry 776 - possible structure discrepancy.
# Failed to process entry 777 - possible structure discrepancy.
# Failed to process entry 778 - possible structure discrepancy.
# Failed to process entry 780 - possible structure discrepancy.
# Failed to process entry 781 - possible structure discrepancy.
# Failed to process entry 782 - possible structure discrepancy.
# Failed to process entry 783 - possible structure discrepancy.
# Failed to process entry 784 - possible structure discrepancy.
# Failed to process entry 785 - possible structure discrepancy.
# Failed to process entry 786 - possible structure discrepancy.
# Failed to process entry 787 - possible structure discrepancy.
# Failed to process entry 790 - possible structure discrepancy.
# Failed to process entry 792 - possible structure discrepancy.
# Failed to process entry 793 - possible structure discrepancy.
# Failed to process entry 794 - possible structure discrepancy.
# Failed to process entry 795 - possible structure discrepancy.
# Failed to process entry 796 - possible structure discrepancy.
# Failed to process entry 797 - possible structure discrepancy.
# Failed to process entry 798 - possible structure discrepancy.
# Failed to process entry 799 - possible structure discrepancy.
# Failed to process entry 800 - possible structure discrepancy.
# Failed to process entry 801 - possible structure discrepancy.
# Failed to process entry 802 - possible structure discrepancy.
# Failed to process entry 803 - possible structure discrepancy.
# Failed to process entry 804 - possible structure discrepancy.
# Failed to process entry 806 - possible structure discrepancy.
# Failed to process entry 807 - possible structure discrepancy.
# Failed to process entry 808 - possible structure discrepancy.
# Failed to process entry 809 - possible structure discrepancy.
# Failed to process entry 810 - possible structure discrepancy.
# Failed to process entry 812 - possible structure discrepancy.
# Failed to process entry 813 - possible structure discrepancy.
# Failed to process entry 814 - possible structure discrepancy.
# Failed to process entry 815 - possible structure discrepancy.
# Failed to process entry 818 - possible structure discrepancy.
# Failed to process entry 819 - possible structure discrepancy.
# Failed to process entry 820 - possible structure discrepancy.
# Failed to process entry 821 - possible structure discrepancy.
# Failed to process entry 822 - possible structure discrepancy.
# Failed to process entry 823 - possible structure discrepancy.
# Failed to process entry 824 - possible structure discrepancy.
# Failed to process entry 825 - possible structure discrepancy.
# Failed to process entry 826 - possible structure discrepancy.
# Failed to process entry 827 - possible structure discrepancy.
# Failed to process entry 829 - possible structure discrepancy.
# Failed to process entry 830 - possible structure discrepancy.
# Failed to process entry 831 - possible structure discrepancy.
# Failed to process entry 832 - possible structure discrepancy.
# Failed to process entry 833 - possible structure discrepancy.
# Failed to process entry 834 - possible structure discrepancy.
# Failed to process entry 835 - possible structure discrepancy.
# Failed to process entry 837 - possible structure discrepancy.
# Failed to process entry 838 - possible structure discrepancy.
# Failed to process entry 839 - possible structure discrepancy.
# Failed to process entry 840 - possible structure discrepancy.
# Failed to process entry 841 - possible structure discrepancy.
# Failed to process entry 844 - possible structure discrepancy.
# Failed to process entry 845 - possible structure discrepancy.
# Failed to process entry 846 - possible structure discrepancy.
# Failed to process entry 847 - possible structure discrepancy.
# Failed to process entry 848 - possible structure discrepancy.
# Failed to process entry 849 - possible structure discrepancy.
# Failed to process entry 850 - possible structure discrepancy.
# Failed to process entry 851 - possible structure discrepancy.
# Failed to process entry 852 - possible structure discrepancy.
# Failed to process entry 853 - possible structure discrepancy.
# Failed to process entry 855 - possible structure discrepancy.
# Failed to process entry 856 - possible structure discrepancy.
# Failed to process entry 857 - possible structure discrepancy.
# Failed to process entry 858 - possible structure discrepancy.
# Failed to process entry 859 - possible structure discrepancy.
# Failed to process entry 860 - possible structure discrepancy.
# Failed to process entry 862 - possible structure discrepancy.
# Failed to process entry 863 - possible structure discrepancy.
# Failed to process entry 864 - possible structure discrepancy.
# Failed to process entry 865 - possible structure discrepancy.
# Failed to process entry 866 - possible structure discrepancy.
# Failed to process entry 867 - possible structure discrepancy.
# Failed to process entry 868 - possible structure discrepancy.
# Failed to process entry 871 - possible structure discrepancy.
# Failed to process entry 872 - possible structure discrepancy.
# Failed to process entry 873 - possible structure discrepancy.
# Failed to process entry 874 - possible structure discrepancy.
# Failed to process entry 876 - possible structure discrepancy.
# Failed to process entry 877 - possible structure discrepancy.
# Failed to process entry 878 - possible structure discrepancy.
# Failed to process entry 879 - possible structure discrepancy.
# Failed to process entry 880 - possible structure discrepancy.
# Failed to process entry 881 - possible structure discrepancy.
# Failed to process entry 882 - possible structure discrepancy.
# Failed to process entry 883 - possible structure discrepancy.
# Failed to process entry 884 - possible structure discrepancy.
# Failed to process entry 886 - possible structure discrepancy.
# Failed to process entry 887 - possible structure discrepancy.
# Failed to process entry 888 - possible structure discrepancy.
# Failed to process entry 889 - possible structure discrepancy.
# Failed to process entry 890 - possible structure discrepancy.
# Failed to process entry 891 - possible structure discrepancy.
# Failed to process entry 892 - possible structure discrepancy.
# Failed to process entry 894 - possible structure discrepancy.
# Failed to process entry 895 - possible structure discrepancy.
# Failed to process entry 897 - possible structure discrepancy.
# Failed to process entry 898 - possible structure discrepancy.
# Failed to process entry 900 - possible structure discrepancy.
# Failed to process entry 901 - possible structure discrepancy.
# Failed to process entry 902 - possible structure discrepancy.
# Failed to process entry 903 - possible structure discrepancy.
# Failed to process entry 904 - possible structure discrepancy.
# Failed to process entry 905 - possible structure discrepancy.
# Failed to process entry 906 - possible structure discrepancy.
# Failed to process entry 908 - possible structure discrepancy.
# Failed to process entry 909 - possible structure discrepancy.
# Failed to process entry 910 - possible structure discrepancy.
# Failed to process entry 911 - possible structure discrepancy.
# Failed to process entry 912 - possible structure discrepancy.
# Failed to process entry 913 - possible structure discrepancy.
# Failed to process entry 914 - possible structure discrepancy.
# Failed to process entry 915 - possible structure discrepancy.
# Failed to process entry 916 - possible structure discrepancy.
# Failed to process entry 917 - possible structure discrepancy.
# Failed to process entry 919 - possible structure discrepancy.
# Failed to process entry 920 - possible structure discrepancy.
# Failed to process entry 921 - possible structure discrepancy.
# Failed to process entry 922 - possible structure discrepancy.
# Failed to process entry 923 - possible structure discrepancy.
# Failed to process entry 924 - possible structure discrepancy.
# Failed to process entry 925 - possible structure discrepancy.
# Failed to process entry 926 - possible structure discrepancy.
# Failed to process entry 929 - possible structure discrepancy.
# Failed to process entry 930 - possible structure discrepancy.
# Failed to process entry 931 - possible structure discrepancy.
# Failed to process entry 932 - possible structure discrepancy.
# Failed to process entry 933 - possible structure discrepancy.
# Failed to process entry 934 - possible structure discrepancy.
# Failed to process entry 935 - possible structure discrepancy.
# Failed to process entry 936 - possible structure discrepancy.
# Failed to process entry 937 - possible structure discrepancy.
# Failed to process entry 938 - possible structure discrepancy.
# Failed to process entry 940 - possible structure discrepancy.
# Failed to process entry 941 - possible structure discrepancy.
# Failed to process entry 942 - possible structure discrepancy.
# Failed to process entry 943 - possible structure discrepancy.
# Failed to process entry 944 - possible structure discrepancy.
# Failed to process entry 945 - possible structure discrepancy.
# Failed to process entry 946 - possible structure discrepancy.
# Failed to process entry 948 - possible structure discrepancy.
# Failed to process entry 949 - possible structure discrepancy.
# Failed to process entry 950 - possible structure discrepancy.
# Failed to process entry 951 - possible structure discrepancy.
# Failed to process entry 952 - possible structure discrepancy.
# Failed to process entry 955 - possible structure discrepancy.
# Failed to process entry 956 - possible structure discrepancy.
# Failed to process entry 957 - possible structure discrepancy.
# Failed to process entry 958 - possible structure discrepancy.
# Failed to process entry 960 - possible structure discrepancy.
# Failed to process entry 961 - possible structure discrepancy.
# Failed to process entry 962 - possible structure discrepancy.
# Failed to process entry 963 - possible structure discrepancy.
# Failed to process entry 964 - possible structure discrepancy.
# Failed to process entry 965 - possible structure discrepancy.
# Failed to process entry 966 - possible structure discrepancy.
# Failed to process entry 967 - possible structure discrepancy.
# Failed to process entry 968 - possible structure discrepancy.
# ...
# Failed to process entry 995 - possible structure discrepancy.
# Failed to process entry 996 - possible structure discrepancy.
# Failed to process entry 999 - possible structure discrepancy.
# Failed to process entry 1000 - possible structure discrepancy.
# Failed to process entry 1001 - possible structure discrepancy.
# Failed to process entry 1002 - possible structure discrepancy.
# Failed to process entry 1003 - possible structure discrepancy.
# Failed to process entry 1004 - possible structure discrepancy.
# Failed to process entry 1005 - possible structure discrepancy.
# Failed to process entry 1006 - possible structure discrepancy.
# Failed to process entry 1007 - possible structure discrepancy.
# Failed to process entry 1009 - possible structure discrepancy.
# Failed to process entry 1010 - possible structure discrepancy.
# Failed to process entry 1011 - possible structure discrepancy.
# Failed to process entry 1012 - possible structure discrepancy.
# Failed to process entry 1013 - possible structure discrepancy.
# Failed to process entry 1014 - possible structure discrepancy.
# Failed to process entry 1015 - possible structure discrepancy.
# Failed to process entry 1017 - possible structure discrepancy.
# Failed to process entry 1018 - possible structure discrepancy.
# Failed to process entry 1019 - possible structure discrepancy.
# Failed to process entry 1020 - possible structure discrepancy.
# Failed to process entry 1023 - possible structure discrepancy.
# Failed to process entry 1024 - possible structure discrepancy.
# Failed to process entry 1025 - possible structure discrepancy.
# Failed to process entry 1026 - possible structure discrepancy.
# Failed to process entry 1028 - possible structure discrepancy.
# Failed to process entry 1029 - possible structure discrepancy.
# Failed to process entry 1030 - possible structure discrepancy.
# Failed to process entry 1031 - possible structure discrepancy.
# Failed to process entry 1032 - possible structure discrepancy.
# Failed to process entry 1033 - possible structure discrepancy.
# Failed to process entry 1034 - possible structure discrepancy.
# Failed to process entry 1035 - possible structure discrepancy.
# Failed to process entry 1036 - possible structure discrepancy.
# Failed to process entry 1037 - possible structure discrepancy.
# Failed to process entry 1038 - possible structure discrepancy.
# Failed to process entry 1039 - possible structure discrepancy.
# Failed to process entry 1041 - possible structure discrepancy.
# Failed to process entry 1042 - possible structure discrepancy.
# Failed to process entry 1043 - possible structure discrepancy.
# Failed to process entry 1044 - possible structure discrepancy.
# Failed to process entry 1045 - possible structure discrepancy.
# Failed to process entry 1046 - possible structure discrepancy.
# Failed to process entry 1047 - possible structure discrepancy.
# Failed to process entry 1049 - possible structure discrepancy.
# Failed to process entry 1051 - possible structure discrepancy.
# Failed to process entry 1052 - possible structure discrepancy.
# Failed to process entry 1054 - possible structure discrepancy.
# Failed to process entry 1055 - possible structure discrepancy.
# Failed to process entry 1056 - possible structure discrepancy.
# Failed to process entry 1057 - possible structure discrepancy.
# Failed to process entry 1058 - possible structure discrepancy.
# Failed to process entry 1059 - possible structure discrepancy.
# Failed to process entry 1060 - possible structure discrepancy.
# Failed to process entry 1061 - possible structure discrepancy.
# Failed to process entry 1062 - possible structure discrepancy.
# Failed to process entry 1064 - possible structure discrepancy.
# Failed to process entry 1065 - possible structure discrepancy.
# Failed to process entry 1066 - possible structure discrepancy.
# Failed to process entry 1067 - possible structure discrepancy.
# Failed to process entry 1068 - possible structure discrepancy.
# Failed to process entry 1069 - possible structure discrepancy.
# Failed to process entry 1071 - possible structure discrepancy.
# Failed to process entry 1072 - possible structure discrepancy.
# Failed to process entry 1073 - possible structure discrepancy.
# Failed to process entry 1074 - possible structure discrepancy.
# Failed to process entry 1075 - possible structure discrepancy.
# Failed to process entry 1077 - possible structure discrepancy.
# Failed to process entry 1079 - possible structure discrepancy.
# Failed to process entry 1081 - possible structure discrepancy.
# Failed to process entry 1082 - possible structure discrepancy.
# Failed to process entry 1083 - possible structure discrepancy.
# Failed to process entry 1084 - possible structure discrepancy.
# Failed to process entry 1085 - possible structure discrepancy.
# Failed to process entry 1086 - possible structure discrepancy.
# Failed to process entry 1087 - possible structure discrepancy.
# Failed to process entry 1088 - possible structure discrepancy.
# Failed to process entry 1089 - possible structure discrepancy.
# Failed to process entry 1090 - possible structure discrepancy.
# Failed to process entry 1091 - possible structure discrepancy.
# Failed to process entry 1093 - possible structure discrepancy.
# Failed to process entry 1094 - possible structure discrepancy.
# Failed to process entry 1095 - possible structure discrepancy.
# Failed to process entry 1096 - possible structure discrepancy.
# Failed to process entry 1098 - possible structure discrepancy.
# Failed to process entry 1099 - possible structure discrepancy.
# Failed to process entry 1100 - possible structure discrepancy.
# Failed to process entry 1101 - possible structure discrepancy.
# Failed to process entry 1102 - possible structure discrepancy.
# Failed to process entry 1105 - possible structure discrepancy.
# Failed to process entry 1106 - possible structure discrepancy.
# Failed to process entry 1107 - possible structure discrepancy.
# Failed to process entry 1108 - possible structure discrepancy.
# Failed to process entry 1109 - possible structure discrepancy.
# Failed to process entry 1110 - possible structure discrepancy.
# Failed to process entry 1111 - possible structure discrepancy.
# Failed to process entry 1112 - possible structure discrepancy.
# Failed to process entry 1113 - possible structure discrepancy.
# Failed to process entry 1114 - possible structure discrepancy.
# Failed to process entry 1115 - possible structure discrepancy.
# Failed to process entry 1116 - possible structure discrepancy.
# Failed to process entry 1117 - possible structure discrepancy.
# Failed to process entry 1119 - possible structure discrepancy.
# Failed to process entry 1120 - possible structure discrepancy.
# Failed to process entry 1121 - possible structure discrepancy.
# Failed to process entry 1122 - possible structure discrepancy.
# Failed to process entry 1124 - possible structure discrepancy.
# Failed to process entry 1125 - possible structure discrepancy.
# Failed to process entry 1126 - possible structure discrepancy.
# Failed to process entry 1128 - possible structure discrepancy.
# Failed to process entry 1129 - possible structure discrepancy.
# Failed to process entry 1130 - possible structure discrepancy.
# Failed to process entry 1132 - possible structure discrepancy.
# Failed to process entry 1133 - possible structure discrepancy.
# Failed to process entry 1134 - possible structure discrepancy.
# Failed to process entry 1135 - possible structure discrepancy.
# Failed to process entry 1136 - possible structure discrepancy.
# Failed to process entry 1137 - possible structure discrepancy.
# Failed to process entry 1138 - possible structure discrepancy.
# Failed to process entry 1139 - possible structure discrepancy.
# Failed to process entry 1140 - possible structure discrepancy.
# Failed to process entry 1142 - possible structure discrepancy.
# Failed to process entry 1143 - possible structure discrepancy.
# Failed to process entry 1144 - possible structure discrepancy.
# Failed to process entry 1145 - possible structure discrepancy.
# Failed to process entry 1146 - possible structure discrepancy.
# Failed to process entry 1148 - possible structure discrepancy.
# Failed to process entry 1149 - possible structure discrepancy.
# Failed to process entry 1150 - possible structure discrepancy.
# Failed to process entry 1151 - possible structure discrepancy.
# Failed to process entry 1152 - possible structure discrepancy.
# Failed to process entry 1153 - possible structure discrepancy.
# Failed to process entry 1154 - possible structure discrepancy.
# Failed to process entry 1155 - possible structure discrepancy.
# Failed to process entry 1158 - possible structure discrepancy.
# Failed to process entry 1159 - possible structure discrepancy.
# Failed to process entry 1160 - possible structure discrepancy.
# Failed to process entry 1161 - possible structure discrepancy.
# Failed to process entry 1162 - possible structure discrepancy.
# Failed to process entry 1163 - possible structure discrepancy.
# Failed to process entry 1164 - possible structure discrepancy.
# Failed to process entry 1165 - possible structure discrepancy.
# Failed to process entry 1166 - possible structure discrepancy.
# Failed to process entry 1168 - possible structure discrepancy.
# Failed to process entry 1169 - possible structure discrepancy.
# Failed to process entry 1170 - possible structure discrepancy.
# Failed to process entry 1171 - possible structure discrepancy.
# Failed to process entry 1172 - possible structure discrepancy.
# Failed to process entry 1173 - possible structure discrepancy.
# Failed to process entry 1177 - possible structure discrepancy.
# Failed to process entry 1178 - possible structure discrepancy.
# Failed to process entry 1180 - possible structure discrepancy.
# Failed to process entry 1181 - possible structure discrepancy.
# Failed to process entry 1182 - possible structure discrepancy.
# Failed to process entry 1183 - possible structure discrepancy.
# Failed to process entry 1184 - possible structure discrepancy.
# Failed to process entry 1185 - possible structure discrepancy.
# Failed to process entry 1186 - possible structure discrepancy.
# Failed to process entry 1187 - possible structure discrepancy.
# Failed to process entry 1188 - possible structure discrepancy.
# Failed to process entry 1191 - possible structure discrepancy.
# Failed to process entry 1192 - possible structure discrepancy.
# Failed to process entry 1193 - possible structure discrepancy.
# Failed to process entry 1194 - possible structure discrepancy.
# Failed to process entry 1195 - possible structure discrepancy.
# Failed to process entry 1196 - possible structure discrepancy.
# Failed to process entry 1197 - possible structure discrepancy.
# Failed to process entry 1198 - possible structure discrepancy.
# Failed to process entry 1200 - possible structure discrepancy.
# Failed to process entry 1201 - possible structure discrepancy.
# Failed to process entry 1202 - possible structure discrepancy.
# Failed to process entry 1203 - possible structure discrepancy.
# Failed to process entry 1204 - possible structure discrepancy.
# Failed to process entry 1205 - possible structure discrepancy.
# Failed to process entry 1206 - possible structure discrepancy.
# Failed to process entry 1209 - possible structure discrepancy.
# Failed to process entry 1210 - possible structure discrepancy.
# Failed to process entry 1211 - possible structure discrepancy.
# Failed to process entry 1212 - possible structure discrepancy.
# Failed to process entry 1214 - possible structure discrepancy.
# Failed to process entry 1215 - possible structure discrepancy.
# Failed to process entry 1217 - possible structure discrepancy.
# Failed to process entry 1218 - possible structure discrepancy.
# Failed to process entry 1219 - possible structure discrepancy.
# Failed to process entry 1220 - possible structure discrepancy.
# Failed to process entry 1221 - possible structure discrepancy.
# Failed to process entry 1222 - possible structure discrepancy.
# Failed to process entry 1223 - possible structure discrepancy.
# Failed to process entry 1224 - possible structure discrepancy.
# Failed to process entry 1225 - possible structure discrepancy.
# Failed to process entry 1227 - possible structure discrepancy.
# Failed to process entry 1228 - possible structure discrepancy.
# Failed to process entry 1229 - possible structure discrepancy.
# Failed to process entry 1230 - possible structure discrepancy.
# Failed to process entry 1231 - possible structure discrepancy.
# Failed to process entry 1232 - possible structure discrepancy.
# Failed to process entry 1235 - possible structure discrepancy.
# Failed to process entry 1236 - possible structure discrepancy.
# Failed to process entry 1237 - possible structure discrepancy.
# Failed to process entry 1238 - possible structure discrepancy.
# Failed to process entry 1239 - possible structure discrepancy.
# Failed to process entry 1240 - possible structure discrepancy.
# Failed to process entry 1241 - possible structure discrepancy.
# Failed to process entry 1242 - possible structure discrepancy.
# Failed to process entry 1243 - possible structure discrepancy.
# Failed to process entry 1245 - possible structure discrepancy.
# Failed to process entry 1246 - possible structure discrepancy.
# Failed to process entry 1247 - possible structure discrepancy.
# Failed to process entry 1248 - possible structure discrepancy.
# Failed to process entry 1249 - possible structure discrepancy.
# Failed to process entry 1250 - possible structure discrepancy.
# Failed to process entry 1252 - possible structure discrepancy.
# Failed to process entry 1253 - possible structure discrepancy.
# Failed to process entry 1254 - possible structure discrepancy.
# Failed to process entry 1255 - possible structure discrepancy.
# Failed to process entry 1257 - possible structure discrepancy.
# Failed to process entry 1258 - possible structure discrepancy.
# Failed to process entry 1259 - possible structure discrepancy.
# Failed to process entry 1260 - possible structure discrepancy.
# Failed to process entry 1261 - possible structure discrepancy.
# Failed to process entry 1262 - possible structure discrepancy.
# Failed to process entry 1264 - possible structure discrepancy.
# Failed to process entry 1266 - possible structure discrepancy.
# Failed to process entry 1267 - possible structure discrepancy.
# Failed to process entry 1268 - possible structure discrepancy.
# Failed to process entry 1270 - possible structure discrepancy.
# Failed to process entry 1272 - possible structure discrepancy.
# Failed to process entry 1273 - possible structure discrepancy.
# Failed to process entry 1274 - possible structure discrepancy.
# Failed to process entry 1275 - possible structure discrepancy.
# Failed to process entry 1277 - possible structure discrepancy.
# Failed to process entry 1282 - possible structure discrepancy.
#                                             tweet_body  \
# 0    Fri, Oct 20, 2023 @ 5:06 PM \nNorthbound Train...
# 1                                North camera is A-OK.
# 2    Fri, Oct 20, 2023 @ 11:08 AM \nSouthbound Trai...
# 3                              https://t.co/RhMmZotOzP
# 4    Fri, Oct 20, 2023 @ 10:13 AM \nNorthbound Trai...
# ..                                                 ...
# 871  Thu, Aug 24, 2023 @ 9:44 PM \nNorthbound Train...
# 872                            https://t.co/QPznsaRNM3
# 873  Thu, Aug 24, 2023 @ 2:46 PM \nNorthbound Train...
# 874                            https://t.co/ioa9HdC6d1
# 875  Thu, Aug 24, 2023 @ 2:46 PM \nNorthbound Train...
#
#                          tweet_time  has_train
# 0    Wed Jul 19 22:57:17 +0000 2017          1
# 1    Fri Oct 20 23:06:50 +0000 2023          0
# 2    Wed Jul 19 22:57:17 +0000 2017          1
# 3    Fri Oct 20 20:56:38 +0000 2023          0
# 4    Wed Jul 19 22:57:17 +0000 2017          1
# ..                              ...        ...
# 871  Fri Aug 25 06:46:46 +0000 2023          1
# 872  Wed Jul 19 22:57:17 +0000 2017          0
# 873  Fri Aug 25 03:44:51 +0000 2023          1
# 874  Wed Jul 19 22:57:17 +0000 2017          0
# 875  Wed Jul 19 22:57:17 +0000 2017          1
#
# [876 rows x 3 columns]

# %%
df.to_csv('trains_Aug24_Oct22.csv')
